# %%
import requests as r
from bs4 import BeautifulSoup as bs
import time

URL = "http://amis.afa.gov.tw/veg/VegProdDayTransInfo.aspx"

headers={
"Accept":"*/*",
'Accept-Encoding':'gzip, deflate',
"Accept-Language":"zh-TW,zh;q=0.8,en-US;q=0.6,en;q=0.4",
"Cache-Control":"no-cache",
"Connection":"keep-alive",
"Content-Length":"25621",
"Content-Type":"application/x-www-form-urlencoded; charset=UTF-8",
"Cookie":"_ga=GA1.3.947818428.1509279105; ASP.NET_SessionId=ij33x0pbmsv0yefbpit5ninb",
"Host":"amis.afa.gov.tw",
"Origin":"http://amis.afa.gov.tw",
"Referer":"http://amis.afa.gov.tw/veg/VegProdDayTransInfo.aspx",
"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/61.0.3163.100 Safari/537.36",
"X-MicrosoftAjax":"Delta=true",
"X-Requested-With":"XMLHttpRequest"
    
}

data = {
'ctl00$ScriptManager_Master':'ctl00$ScriptManager_Master|ctl00$contentPlaceHolder$btnQuery',
'ctl00$contentPlaceHolder$ucDateScope$rblDateScope':'D',
'ctl00$contentPlaceHolder$ucSolarLunar$radlSolarLunar':'S',
'ctl00$contentPlaceHolder$txtSTransDate':'106/11/06',
'ctl00$contentPlaceHolder$txtETransDate':'106/11/06',
'ctl00$contentPlaceHolder$txtMarket':'全部市場',
'ctl00$contentPlaceHolder$hfldMarketNo':'ALL',
'ctl00$contentPlaceHolder$txtProduct':'全部產品',
'ctl00$contentPlaceHolder$hfldProductNo':'ALL',
'ctl00$contentPlaceHolder$hfldProductType':'A',
'__EVENTTARGET':'',
'__EVENTARGUMENT':'',
'__VIEWSTATE':'...',
'__VIEWSTATEGENERATOR':'924237A5',
'__EVENTVALIDATION':'',
'__ASYNCPOST':'true',
'ctl00$contentPlaceHolder$btnQuery':'查詢'
}

resp = r.post(URL, headers=headers,data=data)
resp.text
# Out:
# '1|#||4|58155|updatePanel|ctl00_contentPlaceHolder_updatePanelMain|\r\n\r\n    <div id="ctl00_contentPlaceHolder_panel">\r\n\t\r\n\r\n    <table width="100%">\r\n        <tr>\r\n            <td align="center" class="table_title">\r\n                <input id="btnPrint" type="button" value="列印" class="butten_org" onclick="PrintContainer(this, \'ctl00_contentPlaceHolder_panel\');" />\r\n                蔬菜\r\n                <span id="ctl00_contentPlaceHolder_lblResultTitle">產品日交易行情</span>\r\n                查詢結果\r\n            </td>\r\n        </tr>\r\n    </table>\r\n    <table width="100%" border="0" cellpadding="2" cellspacing="1">\r\n        <tr>\r\n            <td width="10%" class="table_title_03">交易日期：</td>\r\n            <td class="main_main_eng">\r\n                <span id="ctl00_contentPlaceHolder_lblTransDate">106/11/06 (農曆:106/09/18)</span>\r\n            </td>\r\n            <td width="10%" class="table_title_03">查詢時間：</td>\r\n            <td class="main_main_eng">\r\n   
# ...

# %%
import pandas as pd
df = pd.read_html(resp.text)
table = df[2]
table.columns = table.iloc[0]
table = table[2:]
table.drop(['平均價(元/公斤)','跟前一交易日比較%','交易量(公斤)','跟前一交易日比較%'], inplace=True, axis = 1)
table.reset_index(drop = True)
# Out:
# C:\Users\Java\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# 0        市場             產品     上價     中價     下價
# 0   514 溪湖鎮     FB1 花椰菜 青梗   45.0   41.0   36.0
# 1   514 溪湖鎮      FC1 胡瓜 黑刺   48.0   34.0   25.8
# 2   514 溪湖鎮        FD1 花胡瓜   51.0   43.0   37.0
# 3   514 溪湖鎮      FE1 冬瓜 白皮   15.0   10.2    5.6
# 4   514 溪湖鎮         FF1 絲瓜   45.0   31.0   20.0
# 5   514 溪湖鎮     FG1 苦瓜 白大米  110.0   75.0   38.0
# 6   514 溪湖鎮      FH3 扁蒲 花蒲   27.3   21.6   12.8
# 7   514 溪湖鎮     FI2 茄子 麻荸茄   80.0   40.0   28.0
# 8   514 溪湖鎮      FJ1 番茄 黑柿   75.0   68.0   63.0
# 9   514 溪湖鎮      FL2 豌豆 紅花  220.0  208.0  200.0
# 10  514 溪湖鎮      FM2 菜豆 青色   80.0   62.0   50.0
# 11  514 溪湖鎮      FN1 敏豆 白豆  120.0  100.0   90.0
# 12  514 溪湖鎮      FN5 敏豆 醜豆  160.0  110.0  100.0
# ...
